# %% [markdown]
# 50124037 - Phạm Quốc Huy

# %% [markdown]
# Nhập các hệ số a,b,c

# %%
import math
import cmath

a = float(input("Nhap he so a (a khac 0): "))
b = float(input("Nhap he so b: "))
c = float(input("Nhap he so c: "))

if a == 0:
    print("Day khong phai phuong trinh bac hai.")

# %% [markdown]
# Tính Delta

# %%
delta = b*b - 4*a*c
print("Delta la:", delta)
# Out:
# Delta la: 1.0

# %% [markdown]
# Giải và in ra nghiệm

# %%
if delta > 0:
    x1 = (-b + math.sqrt(delta)) / (2*a)
    x2 = (-b - math.sqrt(delta)) / (2*a)
    print("Phuong trinh co 2 nghiem phan biet:")
    print("x1 =", x1)
    print("x2 =", x2)

elif delta == 0:
    x = -b / (2*a)
    print("Phuong trinh co nghiem kep:")
    print("x1 = x2 =", x)

else:
    x1 = (-b + cmath.sqrt(delta)) / (2*a)
    x2 = (-b - cmath.sqrt(delta)) / (2*a)
    print("Phuong trinh co 2 nghiem phuc lien hop:")
    print("x1 =", x1)
    print("x2 =", x2)
# Out:
# Phuong trinh co 2 nghiem phan biet:
# x1 = 3.0
# x2 = 2.0
