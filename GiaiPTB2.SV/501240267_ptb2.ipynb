# %% [markdown]
# Giải phương trình bậc 2
# Lê Tuấn Khang mssv 501240267

# %%
import math

a = float(input('Nhập a: '))
b = float(input('Nhập b: '))
c = float(input('Nhập c: '))

print('a =', a)
print('b =', b)
print('c =', c)
# Out:
# a = 4.0
# b = 8.0
# c = 1.0

# %% [markdown]
# lap delta

# %%
delta = b*b - 4*a*c
print("Delta =", delta)
# Out:
# Delta = 48.0

# %% [markdown]
# Giải phương trình

# %%
if a == 0:
    if b == 0:
        print("Phương trình vô nghiệm" if c != 0 else "Phương trình có vô số nghiệm")
    else:
        print("Nghiệm x =", -c/b)
else:
    if delta < 0:
        print("Phương trình vô nghiệm")
    elif delta == 0:
        x = -b / (2*a)
        print("Phương trình có nghiệm kép x =", x)
    else:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print("x1 =", x1, ", x2 =", x2)
# Out:
# x1 = -0.1339745962155614 , x2 = -1.8660254037844386
