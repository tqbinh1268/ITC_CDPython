# %%
import numpy as np
import pandas as pd

df = pd.read_csv("./Data/customers-100.csv")
df.to_html("output.html", index=False)
print("Wrote output.html")
# data = np.np.loadtxt("./Data/customers-100.csv", delimiter=",", skip_header=1)
# print(data.shape)
# print(data[:5])
