# %% [markdown]
# LAB 3
#
# Bài 1: (2đ) Hoàn thiện đoạn chương trình sau
#
# import numpy as np
#
# # Tạo một mảng NumPy để lưu trữ danh sách sản phẩm ban đầu
# product_list = np.array(["Máy giặt", "Tủ lạnh", "Lò vi sóng", "Điện thoại", "Máy tính bảng"])
#
# def add_product(product):
#     global product_list
#     # Hoàn thiện hàm THÊM sau
#     # product_list = np.append(...)
#     print(f"Sản phẩm '{product}' đã được thêm vào danh sách.")
#
# def delete_product(index_or_name):
#     global product_list
#     try:
#         index_or_name = int(index_or_name)
#         if index_or_name >= 0 and index_or_name < len(product_list):
#             deleted_product = product_list[index_or_name]
#             # Hoàn thiện hàm XÓA sau
#             # product_list = np.delete(...)
#             print(f"Sản phẩm '{deleted_product}' đã bị xóa khỏi danh sách.")
#         else:
#             print("Chỉ mục không hợp lệ.")
#     except ValueError:
#         if index_or_name in product_list:
#             index = np.where(product_list == index_or_name)
#             deleted_product = product_list[index[0][0]]
#             # Hoàn thiện hàm XÓA sau
#             # product_list = np.delete(...)
#             print(f"Sản phẩm '{deleted_product}' đã bị xóa khỏi danh sách.")
#         else:
#             print("Sản phẩm không tồn tại trong danh sách.")
#
# def display_product_list():
#     print("Danh sách sản phẩm:")
#     for idx, product in enumerate(product_list):
#         print(f"{idx}. {product}")
#
# # Menu chương trình
# while True:
#     print("\n------ MENU ------")
#     print("1. Thêm sản phẩm")
#     print("2. Xóa sản phẩm")
#     print("3. Hiển thị danh sách sản phẩm")
#     print("4. Thoát")
#
#     choice = input("Chọn chức năng (1-4): ")
#
#     if choice == '1':
#         new_product = input("Nhập tên sản phẩm mới: ")
#         add_product(new_product)
#     elif choice == '2':
#         index_or_name = input("Nhập chỉ mục hoặc tên sản phẩm cần xóa: ")
#         delete_product(index_or_name)
#     elif choice == '3':
#         display_product_list()
#     elif choice == '4':
#         print("Kết thúc chương trình.")
#         break
#     else:
#         print("Chức năng không hợp lệ. Vui lòng chọn từ 1 đến 4.")
#
# Bài 2: (2đ) Quản lý danh sách môn học
# Hãy viết một đoạn code Python sử dụng mảng NumPy để lưu trữ danh sách các môn học của bạn và thực hiện các chức năng sau:
# 1.	Thêm môn học mới: Thêm một môn học mới vào danh sách.
# 2.	Xóa môn học: Xóa một môn học khỏi danh sách dựa trên chỉ mục hoặc tên của môn học.
# 3.	Hiển thị danh sách môn học: Hiển thị toàn bộ danh sách các môn học.
#
# Bài 3: (2đ) Hãy viết một chương trình sử dụng thư viện NumPy trong Python để thực hiện các công việc sau:
# 1.	Sắp xếp Mảng Một Chiều:
# -	Tạo một mảng 1 chiều ngẫu nhiên.
# -	Sử dụng NumPy để sắp xếp mảng này theo thứ tự tăng dần và giảm dần.
# -	In ra mảng ban đầu và hai phiên bản đã sắp xếp.
#
# 2.	Sắp xếp Mảng Hai Chiều:
# -	Tạo một mảng 2 chiều với các giá trị ngẫu nhiên.
# -	Sử dụng NumPy để sắp xếp mảng này theo hai tiêu chí: sắp xếp theo hàng (theo chiều ngang) và sắp xếp theo cột (theo chiều dọc).
# -	In ra mảng ban đầu và hai phiên bản đã sắp xếp theo hàng và theo cột.
#
# Bài 4: (2đ) Luyện Tập Các Hàm Tìm Kiếm
# 1.	Tìm Kiếm Trong Mảng 1 Chiều:
# -	Tạo một mảng 1 chiều ngẫu nhiên.
# -	Sử dụng các hàm tìm kiếm trong NumPy như np.where, np.argmax, np.argmin để:
# -	Tìm vị trí của các phần tử có giá trị lớn hơn một ngưỡng nhất định.
# -	Tìm vị trí của phần tử lớn nhất và nhỏ nhất trong mảng.
# 2.	Tìm Kiếm Trong Mảng 2 Chiều:
# -	Tạo một mảng 2 chiều với các giá trị ngẫu nhiên.
# -	Tìm vị trí của các phần tử có giá trị lớn hơn một ngưỡng nhất định.
# -	Tìm vị trí của phần tử lớn nhất và nhỏ nhất trong mảng 2 chiều.
