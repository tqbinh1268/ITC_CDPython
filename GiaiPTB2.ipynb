# %% [markdown]
# MSSV:
# Họ Và Tên:

# %% [markdown]
# Nhập abc
# sau khi nhập a,b,c thì xuất ra

# %%
a = input('Nhap a: ')
b = input('Nhap b: ')
c = input('Nhap c: ')
print('a =', a)
print('b =', b)
print('c =', c)
# Out:
# a = 1
# b = 6
# c = 2

# %% [markdown]
# Lập Delta

# %%
delta = float(b)**2 - 4*float(a)*float(c)
print('Delta =', delta)
# Out:
# Delta = 28.0

# %% [markdown]
# Xét Delta và tìm nghiệm
